# %%
# !pip install autoviz
# Out:
# Requirement already satisfied: autoviz in /usr/local/lib/python3.13/dist-packages (0.1.905)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.13/dist-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.9.6)
# Requirement already satisfied: emoji in /usr/local/lib/python3.13/dist-packages (from autoviz) (2.16.0)
# Requirement already satisfied: pyamg in /usr/local/lib/python3.13/dist-packages (from autoviz) (5.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.13/dist-packages (from autoviz) (0.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.13/dist-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.13/dist-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from autoviz) (2025.12.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.13/dist-packages (from autoviz) (4.16.0)
# Requirement already satisfied: pandas-dq>=1.29 in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.13/dist-packages (from autoviz) (2.1.3)
# Requirement already satisfied: hvplot>=0.9.2 in /usr/local/lib/python3.13/dist-packages (from autoviz) (0.12.2)
# Requirement already satisfied: holoviews>=1.16.0 in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.23.2)
# Requirement already satisfied: panel>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from autoviz) (1.9.4)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.13/dist-packages (from autoviz) (2.2.3)
# Requirement already satisfied: matplotlib>3.7.4 in /usr/local/lib/python3.13/dist-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /usr/local/lib/python3.13/dist-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (3.8.2)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (3.2.1)
# Requirement already satisfied: narwhals>=2 in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (2.25.0)
# Requirement already satisfied: param<3.0,>=2.0 in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (2.9.0.post0)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.13/dist-packages (from holoviews>=1.16.0->autoviz) (3.0.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from hvplot>=0.9.2->autoviz) (26.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>3.7.4->autoviz) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.0->autoviz) (2026.3)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (3.10.3)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (0.6.1)
# Requirement already satisfied: nh3 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (0.3.7)
# Requirement already satisfied: panel-material-ui>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (0.14.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.0->autoviz) (4.67.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->autoviz) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->autoviz) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from nltk->autoviz) (8.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.13/dist-packages (from nltk->autoviz) (2025.11.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.13/dist-packages (from statsmodels->autoviz) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statsmodels->autoviz) (1.2.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.13/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.13/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.13/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.5.7)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.13/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2026.3.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->autoviz) (2.0.1)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->autoviz) (2.4.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn->autoviz) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->holoviews>=1.16.0->autoviz) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.0->autoviz) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.0->autoviz) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.0->autoviz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.0->autoviz) (2026.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.3)

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass   sex     age  sibsp  parch   fare   embarked class   \
# 0      0        3      male  22.0    1      0     7.2500     S     Third
# 1      1        1    female  38.0    1      0    71.2833     C     First
# 2      1        3    female  26.0    0      0     7.9250     S     Third
# 3      1        1    female  35.0    1      0    53.1000     S     First
# 4      0        3      male  35.0    0      0     8.0500     S     Third
#
#    who    adult_male deck embark_town  alive  alone
# 0    man      True    NaN  Southampton    no  False
# 1  woman     False      C    Cherbourg   yes  False
# 2  woman     False    NaN  Southampton   yes   True
# 3  woman     False      C  Southampton   yes  False
# 4    man      True    NaN  Southampton    no   True

# %%
df.to_csv('titanic.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = 'titanic.csv'
sep = ","
dft = AV.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (891, 16)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  5
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  4
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     16 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_c9448_row0_col0, #T_c9448_row0_col2, #T_c9448_row0_col3, #T_c9448_row0_col4, #T_c9448_row0_col5, #T_c9448_row1_col0, #T_c9448_row1_col2, #T_c9448_row1_col3, #T_c9448_row1_col4, #T_c9448_row1_col5, #T_c9448_row2_col0, #T_c9448_row2_col2, #T_c9448_row2_col3, #T_c9448_row2_col4, #T_c9448_row2_col5, #T_c9448_row3_col0, #T_c9448_row3_col2, #T_c9448_row3_col3, #T_c9448_row3_col4, #T_c9448_row3_col5, #T_c9448_row4_col0, #T_c9448_row4_col2, #T_c9448_row4_col3, #T_c9448_row4_col4, #T_c9448_row4_col5, #T_c9448_row5_col0, #T_c9448_row5_col2, #T_c9448_row5_col3, #T_c9448_row5_col4, #T_c9448_row5_col5, #T_c9448_row6_col0, #T_c9448_row6_col2, #T_c9448_row6_col3, #T_c9448_row6_col4, #T_c9448_row6_col5, #T_c9448_row7_col0, #T_c9448_row7_col2, #T_c9448_row7_col3, #T_c9448_row7_col4, #T_c9448_row7_col5, #T_c9448_row8_col0, #T_c9448_row8_col2, #T_c9448_row8_col3, #T_c9448_row8_col4, #T_c9448_row8_col5, #T_c9448_row9_col0, #T_c9448_row9_col2, #T_c9448_row9_col3, #T_c9448_row9_col4, #T_c9448_row9_col5, #T_c9448_row10_col0, #T_c9448_row10_col2, #T_c9448_row10_col3, #T_c9448_row10_col4, #T_c9448_row10_col5, #T_c9448_row11_col0, #T_c9448_row11_col2, #T_c9448_row11_col3, #T_c9448_row11_col4, #T_c9448_row11_col5, #T_c9448_row12_col0, #T_c9448_row12_col2, #T_c9448_row12_col3, #T_c9448_row12_col4, #T_c9448_row12_col5, #T_c9448_row13_col0, #T_c9448_row13_col2, #T_c9448_row13_col3, #T_c9448_row13_col4, #T_c9448_row13_col5, #T_c9448_row14_col0, #T_c9448_row14_col2, #T_c9448_row14_col3, #T_c9448_row14_col4, #T_c9448_row14_col5, #T_c9448_row15_col0, #T_c9448_row15_col2, #T_c9448_row15_col3, #T_c9448_row15_col4, #T_c9448_row15_col5 {
#   font-family: Segoe UI;
# }
# #T_c9448_row0_col1, #T_c9448_row1_col1, #T_c9448_row2_col1, #T_c9448_row3_col1, #T_c9448_row5_col1, #T_c9448_row6_col1, #T_c9448_row7_col1, #T_c9448_row8_col1, #T_c9448_row9_col1, #T_c9448_row10_col1, #T_c9448_row11_col1, #T_c9448_row13_col1, #T_c9448_row14_col1, #T_c9448_row15_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c9448_row4_col1 {
#   background-color: #fcb99f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c9448_row12_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_c9448" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9448_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_c9448_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_c9448_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_c9448_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_c9448_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_c9448_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9448_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_c9448_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_c9448_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_c9448_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_c9448_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_c9448_row0_col4" class="data row0 col4" >890.000000</td>
#       <td id="T_c9448_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row1" class="row_heading level0 row1" >survived</th>
#       <td id="T_c9448_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_c9448_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c9448_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c9448_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_c9448_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_c9448_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row2" class="row_heading level0 row2" >pclass</th>
#       <td id="T_c9448_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_c9448_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_c9448_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c9448_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_c9448_row2_col4" class="data row2 col4" >3.000000</td>
#       <td id="T_c9448_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row3" class="row_heading level0 row3" >sex</th>
#       <td id="T_c9448_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c9448_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_c9448_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_c9448_row3_col3" class="data row3 col3" ></td>
#       <td id="T_c9448_row3_col4" class="data row3 col4" ></td>
#       <td id="T_c9448_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row4" class="row_heading level0 row4" >age</th>
#       <td id="T_c9448_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_c9448_row4_col1" class="data row4 col1" >19.865320</td>
#       <td id="T_c9448_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_c9448_row4_col3" class="data row4 col3" >0.420000</td>
#       <td id="T_c9448_row4_col4" class="data row4 col4" >80.000000</td>
#       <td id="T_c9448_row4_col5" class="data row4 col5" >177 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 11 outliers greater than upper bound (64.81) or lower than lower bound(-6.69). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row5" class="row_heading level0 row5" >sibsp</th>
#       <td id="T_c9448_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_c9448_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_c9448_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_c9448_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_c9448_row5_col4" class="data row5 col4" >8.000000</td>
#       <td id="T_c9448_row5_col5" class="data row5 col5" >Column has 46 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row6" class="row_heading level0 row6" >parch</th>
#       <td id="T_c9448_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_c9448_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_c9448_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_c9448_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_c9448_row6_col4" class="data row6 col4" >6.000000</td>
#       <td id="T_c9448_row6_col5" class="data row6 col5" >Column has 213 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row7" class="row_heading level0 row7" >fare</th>
#       <td id="T_c9448_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_c9448_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_c9448_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_c9448_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_c9448_row7_col4" class="data row7 col4" >512.329200</td>
#       <td id="T_c9448_row7_col5" class="data row7 col5" >Column has 116 outliers greater than upper bound (65.63) or lower than lower bound(-26.72). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c9448_level0_row8" class="row_heading level0 row8" >embarked</th>
#       <td id="T_c9448_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_c9448_row8_col1" class="data row8 col1" >0.224467</td>
#       <td id="T_c9448_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_c9448_row8_col3" class="data row8 col3" ></td>
#       <td id="T_c9448_row8_col4" class="data row8 col4" ></td>
#       <td id="T_c944
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 15 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
